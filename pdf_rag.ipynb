# %%
 # %pip install -U langchain-community pypdf
# Out:
# Requirement already satisfied: langchain-community in d:\aig\gen ai\virtual\lib\site-packages (0.4.2)
# Requirement already satisfied: pypdf in d:\aig\gen ai\virtual\lib\site-packages (6.13.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (1.4.7)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (0.8.16)
# Requirement already satisfied: numpy>=1.26.2 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\aig\gen ai\virtual\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\aig\gen ai\virtual\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\aig\gen ai\virtual\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\aig\gen ai\virtual\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\aig\gen ai\virtual\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\aig\gen ai\virtual\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in d:\aig\gen ai\virtual\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\aig\gen ai\virtual\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.17)
# Requirement already satisfied: packaging>=23.2.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\aig\gen ai\virtual\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\aig\gen ai\virtual\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\aig\gen ai\virtual\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in d:\aig\gen ai\virtual\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.5.20)
# Requirement already satisfied: greenlet>=1 in d:\aig\gen ai\virtual\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.2)
# Requirement already satisfied: anyio in d:\aig\gen ai\virtual\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.13.0)
# Requirement already satisfied: httpcore==1.* in d:\aig\gen ai\virtual\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\aig\gen ai\virtual\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\aig\gen ai\virtual\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Import Libraries

# %%
from langchain_community.document_loaders import PyPDFLoader
# Out:
# C:\Users\mithl\AppData\Local\Temp\ipykernel_12020\261415334.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader(
           file_path = "D:\AIG\Gen AI\LLMs.pdf"
)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\A'
# <>:2: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\mithl\AppData\Local\Temp\ipykernel_12020\1997620416.py:2: SyntaxWarning: invalid escape sequence '\A'
#   file_path = "D:\AIG\Gen AI\LLMs.pdf"

# %%
pages = loader.load()

# %%
print(len(pages))
# Out:
# 26

# %%
# %pip install -U langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in d:\aig\gen ai\virtual\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-text-splitters) (1.4.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.16)
# Requirement already satisfied: packaging>=23.2.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\aig\gen ai\virtual\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: anyio in d:\aig\gen ai\virtual\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.13.0)
# Requirement already satisfied: certifi in d:\aig\gen ai\virtual\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in d:\aig\gen ai\virtual\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in d:\aig\gen ai\virtual\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.18)
# Requirement already satisfied: h11>=0.16 in d:\aig\gen ai\virtual\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\aig\gen ai\virtual\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\aig\gen ai\virtual\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1200, chunk_overlap=600)
chunks = text_splitter.split_documents(pages)

# %%
print(len(chunks))
# Out:
# 126

# %%
print(chunks[100])
# Out:
# page_content='significant_genes_df = data_mutsig[data_mutsig['q'] < 0.1]
# # Sort the genes by their significance
# significant_genes_df = significant_genes_df.sort_values(by='q', ascending=True)
# # Extract the gene names
# significant_genes = significant_genes_df['gene'].tolist()
# # Save the list to a file
# with open("significant_genes.txt", "w") as f:
#   for gene in significant_genes:
#     f.write(f"{gene}")
# # Print the list of significant genes
# print(significant_genes)
# assert mutation_indicator["PATIENT_ID"].nunique() == 130
# assert mutation_indicator["Hugo_Symbol"].nunique() == 95
# assert mutation_indicator["Silent"].sum() == 159
# assert mutation_indicator["Splice site"].sum() == 57
# assert mutation_indicator["Nonsense"].sum() == 119
# assert mutation_indicator["Frame shift"].sum() == 0
# assert mutation_indicator["In frame indel"].sum() == 0
# Question
# Prefix code
# Testing cases
# Extended Fig. 2: An example of Python coding task with the input question, prefix code, and
# testing cases.
# 19' metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-30T00:16:25+00:00', 'author': '', 'keywords': '', 'moddate': '2024-10-30T00:16:25+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'D:\\AIG\\Gen AI\\LLMs.pdf', 'total_pages': 26, 'page': 18, 'page_label': '19'}

# %%
# %pip install langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in d:\aig\gen ai\virtual\lib\site-packages (4.2.5)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-google-genai) (2.8.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.2 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-google-genai) (1.4.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in d:\aig\gen ai\virtual\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in d:\aig\gen ai\virtual\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.53.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in d:\aig\gen ai\virtual\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in d:\aig\gen ai\virtual\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in d:\aig\gen ai\virtual\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in d:\aig\gen ai\virtual\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\aig\gen ai\virtual\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in d:\aig\gen ai\virtual\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.8.16)
# Requirement already satisfied: packaging>=23.2.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\aig\gen ai\virtual\lib\site-packages (from langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.16.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\aig\gen ai\virtual\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in d:\aig\gen ai\virtual\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\aig\gen ai\virtual\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in d:\aig\gen ai\virtual\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (48.0.0)
# Requirement already satisfied: certifi in d:\aig\gen ai\virtual\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in d:\aig\gen ai\virtual\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\aig\gen ai\virtual\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\aig\gen ai\virtual\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\aig\gen ai\virtual\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.2->langchain-google-genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\aig\gen ai\virtual\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\aig\gen ai\virtual\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in d:\aig\gen ai\virtual\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in d:\aig\gen ai\virtual\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Requirement already satisfied: pycparser in d:\aig\gen ai\virtual\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import getpass
import os

if not os.getenv("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API key: ")

# %%
# %pip install -qU langchain-google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embedder = GoogleGenerativeAIEmbeddings(
    model = "gemini-embedding-001"
)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
# %pip install -qU langchain-qdrant
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient

# %%
vector_store = QdrantVectorStore.from_documents(
    documents=[],
    url="http://localhost:6333",
    collection_name="pdf_collection",
    embedding=embedder
)

# %%
vector_store.add_documents(documents=chunks)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File d:\AIG\Gen AI\virtual\Lib\site-packages\langchain_google_genai\embeddings.py:449, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     448 try:
# --> 449     result = self.client.models.embed_content(
#     450         model=self.model,
#     451         contents=[{"parts": [{"text": text}]} for text in batch],
#     452         config=config,
#     453     )
#     454 except ClientError as e:
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\google\genai\models.py:6340, in Models.embed_content(self, model, contents, config)
#    6339     contents = t.t_contents(contents)  # type: ignore[assignment]
# -> 6340   return self._embed_content(model=model, contents=contents, config=config)
#    6342 if t.t_is_vertex_embed_content_model(model):
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\google\genai\models.py:5145, in Models._embed_content(self, model, contents, content, embedding_api_type, config)
#    5143 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5145 response = self._api_client.request(
#    5146     'post', path, request_dict, http_options
#    5147 )
#    5149 response_dict = {} if not response.body else json.loads(response.body)
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\google\genai\_api_client.py:1611, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1608 http_request = self._build_request(
#    1609     http_method, path, request_dict, http_options
#    1610 )
# -> 1611 response = self._request(http_request, http_options, stream=False)
#    1612 response_body = (
#    1613     response.response_stream[0] if response.response_stream else ''
#    1614 )
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\google\genai\_api_client.py:1404, in BaseApiClient._request(self, http_request, http_options, stream)
#    1402     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1404 return self._retry(self._request_once, http_request, stream)
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\google\genai\_api_client.py:1381, in BaseApiClient._request_once(self, http_request, stream)
#    1380   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1381 errors.APIError.raise_for_response(response)
#    1382 return HttpResponse(
#    1383     response.headers, response if stream else [response.text]
#    1384 )
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 100, model: gemini-embedding-1.0\nPlease retry in 43.482178442s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/embed_content_free_tier_requests', 'quotaId': 'EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-embedding-1.0'}, 'quotaValue': '100'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '43s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 vector_store.add_documents(documents=chunks)
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\langchain_core\vectorstores\base.py:258, in VectorStore.add_documents(self, documents, **kwargs)
#     256     texts = [doc.page_content for doc in documents]
#     257     metadatas = [doc.metadata for doc in documents]
# --> 258     return self.add_texts(texts, metadatas, **kwargs)
#     259 msg = (
#     260     f"`add_documents` and `add_texts` has not been implemented "
#     261     f"for {self.__class__.__name__} "
#     262 )
#     263 raise NotImplementedError(msg)
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\langchain_qdrant\qdrant.py:510, in QdrantVectorStore.add_texts(self, texts, metadatas, ids, batch_size, **kwargs)
#     503 """Add texts with embeddings to the `VectorStore`.
#     504
#     505 Returns:
#     506     List of ids from adding the texts into the `VectorStore`.
#     507
#     508 """
#     509 added_ids = []
# --> 510 for batch_ids, points in self._generate_batches(
#     511     texts, metadatas, ids, batch_size
#     512 ):
#     513     self.client.upsert(
#     514         collection_name=self.collection_name, points=points, **kwargs
#     515     )
#     516     added_ids.extend(batch_ids)
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\langchain_qdrant\qdrant.py:1060, in QdrantVectorStore._generate_batches(self, texts, metadatas, ids, batch_size)
#    1050 batch_metadatas = list(islice(metadatas_iterator, batch_size)) or None
#    1051 batch_ids = list(islice(ids_iterator, batch_size))
#    1052 points = [
#    1053     models.PointStruct(
#    1054         id=point_id,
#    1055         vector=vector,
#    1056         payload=payload,
#    1057     )
#    1058     for point_id, vector, payload in zip(
#    1059         batch_ids,
# -> 1060         self._build_vectors(batch_texts),
#    1061         self._build_payloads(
#    1062             batch_texts,
#    1063             batch_metadatas,
#    1064             self.content_payload_key,
#    1065             self.metadata_payload_key,
#    1066         ),
#    1067         strict=False,
#    1068     )
#    1069 ]
#    1071 yield batch_ids, points
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\langchain_qdrant\qdrant.py:1104, in QdrantVectorStore._build_vectors(self, texts)
#    1102 if self.retrieval_mode == RetrievalMode.DENSE:
#    1103     embeddings = self._require_embeddings("DENSE mode")
# -> 1104     batch_embeddings = embeddings.embed_documents(list(texts))
#    1105     return [
#    1106         {
#    1107             self.vector_name: vector,
#    1108         }
#    1109         for vector in batch_embeddings
#    1110     ]
#    1112 if self.retrieval_mode == RetrievalMode.SPARSE:
#
# File d:\AIG\Gen AI\virtual\Lib\site-packages\langchain_google_genai\embeddings.py:456, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     454 except ClientError as e:
#     455     msg = f"Error embedding content ({e.status}): {e}"
# --> 456     raise GoogleGenerativeAIError(msg) from e
#     457 except Exception as e:
#     458     msg = f"Error embedding content: {e}"
#
# GoogleGenerativeAIError: Error embedding content (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 100, model: gemini-embedding-1.0\nPlease retry in 43.482178442s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/embed_content_free_tier_requests', 'quotaId': 'EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-embedding-1.0'}, 'quotaValue': '100'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '43s'}]}}

# %%
retriver = QdrantVectorStore.from_existing_collection(
    embedding=embedder,
    collection_name="pdf_collection",
    url="http://localhost:6333",
)

# %%
query = "What is LLMs?"
found_docs = retriver.similarity_search(query)
found_docs
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-30T00:16:25+00:00', 'author': '', 'keywords': '', 'moddate': '2024-10-30T00:16:25+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'D:\\AIG\\Gen AI\\LLMs.pdf', 'total_pages': 26, 'page': 1, 'page_label': '2', '_id': 'bfab611b-95f2-41cd-a9ee-4fb60f7078d0', '_collection_name': 'pdf_collection'}, page_content='can be automated by LLMs. We benchmarked six state-of-the-art LLMs using various\nmethods, including chain-of-thought prompting, few-shot prompting, automatic prompt-\ning, self-reflection, and retrieval-augmented generation (Fig. 1f). Our analysis focused on\nboth the accuracy and quality of the code generated by these models. While we found that\ncurrent LLMs are not yet capable of fully automating complex clinical data science tasks,\nthey do generate code that is highly similar to the correct final solutions. Building on this\ninsight, we investigated the development of a platform designed to facilitate collaboration\nbetween human experts and artificial intelligence (AI) to streamline coding tasks. This\nplatform aims to enhance the productivity of clinical researchers by integrating LLMs into\nestablished data science workflows, with a focus on user-friendliness and the reliability of\nthe outputs. Our results demonstrated that the platform significantly improved human\nexperts’ efficiency in executing data science tasks, highlighting the promising future of\n2'),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-30T00:16:25+00:00', 'author': '', 'keywords': '', 'moddate': '2024-10-30T00:16:25+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'D:\\AIG\\Gen AI\\LLMs.pdf', 'total_pages': 26, 'page': 5, 'page_label': '6', '_id': '6b3d3fa9-92a8-4e01-8b7a-3a739f46d15b', '_collection_name': 'pdf_collection'}, page_content='LLMs: GPT-4o, 24 GPT-4o-mini,25 Sonnet,26 Opus,27 Gemini-pro,28 and Gemini-flash. 28\nThese models represent a diverse set of advanced generalist LLMs capable of perform-\ning code generation based on input instructions. To explore their effectiveness and po-\ntential room for improvement in clinical research data science tasks, we applied several\nadaptation methods: chain-of-thought, 29 few-shot prompting, 30 automatic prompting, 31\nself-reflection,12 and retrieval-augmented generation (RAG). 32\nFor evaluation, we assessed the combinations of models and adaptation methods across\nthree tasks: code generation, code debugging, and human-AI collaboration. The first two\ntasks were used to measure the models’ accuracy in automating the coding process. We\nemployed Pass@k as the primary metric, where k represents the number of attempts the\nmodel is allowed to make to solve a coding task. This metric behaves like the probability\nthat at least one out of the k attempts is correct. Specifically, we selected k = 1 as a strict\nbenchmark to evaluate how well LLMs can automate tasks on the first attempt, providing\ninsight into their immediate accuracy. Additionally, we used k = 5 as a more relaxed'),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-30T00:16:25+00:00', 'author': '', 'keywords': '', 'moddate': '2024-10-30T00:16:25+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'D:\\AIG\\Gen AI\\LLMs.pdf', 'total_pages': 26, 'page': 1, 'page_label': '2', '_id': '4c519671-21f8-4e24-baed-a74a3c4cebcb', '_collection_name': 'pdf_collection'}, page_content='els (LLMs), which have demonstrated strong capabilities in tasks like code completion. 5\nContinuous efforts have been made in developing more powerful code-specific LLMs,6–8 re-\nfining prompting strategies,9 integrating external knowledge through retrieval-augmented\ngeneration (RAG),10, 11and enabling LLMs’ self-reflection.12 These advancements further\nlead to the LLM-based platform for software development 13 and data analysis. 14 While\nLLMs have been evaluated for general programming tests, 5, 15–17software engineering,18\nand data analysis , 19, 20 assessments specifically targeting clinical research data science\nremain scarce. In medicine, recent works have introduced LLMs to automate machine\nlearning modeling21 and support bioinformatics tool development,22 but they do not cover\nbroad data science tasks. Therefore, this paper seeks to build a comprehensive code gen-\neration dataset to assess to which extent the cutting-edge LLMs can automate clinical\nresearch data analysis, modeling, and visualization.\nOur objective was to evaluate the practical utility of LLMs in handling complex clinical'),
#  Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2024-10-30T00:16:25+00:00', 'author': '', 'keywords': '', 'moddate': '2024-10-30T00:16:25+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'D:\\AIG\\Gen AI\\LLMs.pdf', 'total_pages': 26, 'page': 10, 'page_label': '11', '_id': 'd54fa672-411f-4d69-a72b-d10454fb2dc6', '_collection_name': 'pdf_collection'}, page_content='that LLM-generated code is close to the correct solution, and Fig. 3e and Fig. 3f indicate\nthat most code executes successfully but fails only at the final testing stages. Additionally,\nLLM self-reflection can resolve most of the bugs. These findings highlight the potential of\nLLMs to assist data scientists in streamlining the coding process in clinical research.\nTo bridge the gap in utilizing LLMs for clinical research and leveraging the insights\nfrom our experiments, we developed a platform that integrates LLMs into data science\nprojects for clinical research. The architecture of this platform is shown in Extended\nFig. 1. The platform is designed to offer an integrated interface for users to:\n• Chat with LLMs to brainstorm and plan analyses, with the ability to query external\nknowledge bases, including webpages, research papers, and other resources.\n• Generate code for data science tasks through interactions with LLMs, allowing users to\nstreamline code writing for complex analyses.\n• Identify and debug errors in the user-provided code, with LLMs proposing solutions to\nimprove the code.\nThe interface supports real-time interactions, allowing users to generate and execute code')]
